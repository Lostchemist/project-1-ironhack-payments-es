# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
cash =  pd.read_csv('./project_dataset/cash_request.csv')
#cash.set_index(['id'], inplace=True)
cash.head()
# Out:
#      id  amount    status                     created_at  \
# 0     5   100.0  rejected  2019-12-10 19:05:21.596873+00
# 1    70   100.0  rejected   2019-12-10 19:50:12.34778+00
# 2     7   100.0  rejected   2019-12-10 19:13:35.82546+00
# 3    10    99.0  rejected  2019-12-10 19:16:10.880172+00
# 4  1594   100.0  rejected  2020-05-06 09:59:38.877376+00
#
#                       updated_at  user_id                   moderated_at  \
# 0   2019-12-11 16:47:42.40783+00    804.0  2019-12-11 16:47:42.405646+00
# 1  2019-12-11 14:24:22.900054+00    231.0  2019-12-11 14:24:22.897988+00
# 2  2019-12-11 09:46:59.779773+00    191.0  2019-12-11 09:46:59.777728+00
# 3  2019-12-18 14:26:18.136163+00    761.0  2019-12-18 14:26:18.128407+00
# 4   2020-05-07 09:21:55.34008+00   7686.0  2020-05-07 09:21:55.320193+00
#
#    deleted_account_id             reimbursement_date  \
# 0                 NaN  2020-01-09 19:05:21.596363+00
# 1                 NaN   2020-01-09 19:50:12.34778+00
# 2                 NaN  2020-01-09 19:13:35.825041+00
# 3                 NaN  2020-01-09 19:16:10.879606+00
# 4                 NaN         2020-06-05 22:00:00+00
#
#   cash_request_received_date money_back_date transfer_type send_at  \
# 0                        NaN             NaN       regular     NaN
# 1                        NaN             NaN       regular     NaN
# 2                        NaN             NaN       regular     NaN
# 3                        NaN             NaN       regular     NaN
# 4                        NaN             NaN       regular     NaN
#
#   recovery_status reco_creation reco_last_update
# 0             NaN           NaN              NaN
# 1             NaN           NaN              NaN
# 2             NaN           NaN              NaN
# 3             NaN           NaN              NaN
# 4             NaN           NaN              NaN

# %%
cash.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23970 entries, 5 to 19886
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   amount                      23970 non-null  float64
#  1   status                      23970 non-null  object
#  2   created_at                  23970 non-null  object
#  3   updated_at                  23970 non-null  object
#  4   user_id                     21867 non-null  float64
#  5   moderated_at                16035 non-null  object
#  6   deleted_account_id          2104 non-null   float64
#  7   reimbursement_date          23970 non-null  object
#  8   cash_request_received_date  16289 non-null  object
#  9   money_back_date             16543 non-null  object
#  10  transfer_type               23970 non-null  object
#  11  send_at                     16641 non-null  object
#  12  recovery_status             3330 non-null   object
#  13  reco_creation               3330 non-null   object
#  14  reco_last_update            3330 non-null   object
# dtypes: float64(3), object(12)
# memory usage: 2.9+ MB

# %%
cash.replace('NaN', None, inplace=True)
cash.head()
# Out:
#       amount    status                     created_at  \
# id
# 5      100.0  rejected  2019-12-10 19:05:21.596873+00
# 70     100.0  rejected   2019-12-10 19:50:12.34778+00
# 7      100.0  rejected   2019-12-10 19:13:35.82546+00
# 10      99.0  rejected  2019-12-10 19:16:10.880172+00
# 1594   100.0  rejected  2020-05-06 09:59:38.877376+00
#
#                          updated_at  user_id                   moderated_at  \
# id
# 5      2019-12-11 16:47:42.40783+00    804.0  2019-12-11 16:47:42.405646+00
# 70    2019-12-11 14:24:22.900054+00    231.0  2019-12-11 14:24:22.897988+00
# 7     2019-12-11 09:46:59.779773+00    191.0  2019-12-11 09:46:59.777728+00
# 10    2019-12-18 14:26:18.136163+00    761.0  2019-12-18 14:26:18.128407+00
# 1594   2020-05-07 09:21:55.34008+00   7686.0  2020-05-07 09:21:55.320193+00
#
#       deleted_account_id             reimbursement_date  \
# id
# 5                    NaN  2020-01-09 19:05:21.596363+00
# 70                   NaN   2020-01-09 19:50:12.34778+00
# 7                    NaN  2020-01-09 19:13:35.825041+00
# 10                   NaN  2020-01-09 19:16:10.879606+00
# 1594                 NaN         2020-06-05 22:00:00+00
#
#      cash_request_received_date money_back_date transfer_type send_at  \
# id
# 5                           NaN             NaN       regular     NaN
# 70                          NaN             NaN       regular     NaN
# 7                           NaN             NaN       regular     NaN
# 10                          NaN             NaN       regular     NaN
# 1594                        NaN             NaN       regular     NaN
#
#      recovery_status reco_creation reco_last_update
# id
# 5                NaN           NaN              NaN
# 70               NaN           NaN              NaN
# 7                NaN           NaN              NaN
# 10               NaN           NaN              NaN
# 1594             NaN           NaN              NaN

# %%
cash.count()
# Out:
# amount                        23970
# status                        23970
# created_at                    23970
# updated_at                    23970
# user_id                       21867
# moderated_at                  16035
# deleted_account_id             2104
# reimbursement_date            23970
# cash_request_received_date    16289
# money_back_date               16543
# transfer_type                 23970
# send_at                       16641
# recovery_status                3330
# reco_creation                  3330
# reco_last_update               3330
# dtype: int64

# %%
print("cash - transfer_type")
print(cash["transfer_type"].unique())
print("cash - status")
print(cash["status"].unique())
print("cash - recovery_status")
print(cash["recovery_status"].unique())
print()
# Out:
# cash - transfer_type
# ['regular' 'instant']
# cash - status
# ['rejected' 'money_back' 'canceled' 'active' 'direct_debit_rejected'
#  'transaction_declined' 'direct_debit_sent']
# cash - recovery_status
# [nan 'completed' 'pending' 'pending_direct_debit' 'cancelled']

# %%
cash.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23970 entries, 5 to 19886
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   amount                      23970 non-null  float64
#  1   status                      23970 non-null  object
#  2   created_at                  23970 non-null  object
#  3   updated_at                  23970 non-null  object
#  4   user_id                     21867 non-null  float64
#  5   moderated_at                16035 non-null  object
#  6   deleted_account_id          2104 non-null   float64
#  7   reimbursement_date          23970 non-null  object
#  8   cash_request_received_date  16289 non-null  object
#  9   money_back_date             16543 non-null  object
#  10  transfer_type               23970 non-null  object
#  11  send_at                     16641 non-null  object
#  12  recovery_status             3330 non-null   object
#  13  reco_creation               3330 non-null   object
#  14  reco_last_update            3330 non-null   object
# dtypes: float64(3), object(12)
# memory usage: 2.9+ MB

# %% [markdown]
# # fees

# %%
fees_data =  pd.read_csv('./project_dataset/fees_data.csv')
fees_data.set_index('id', inplace=True)
fees_data.head()
# Out:
#        cash_request_id             type    status               category  \
# id
# 6537           14941.0  instant_payment  rejected                    NaN
# 6961           11714.0         incident  accepted  rejected_direct_debit
# 16296          23371.0  instant_payment  accepted                    NaN
# 20775          26772.0  instant_payment  accepted                    NaN
# 11242          19350.0  instant_payment  accepted                    NaN
#
#        total_amount                              reason  \
# id
# 6537            5.0  Instant Payment Cash Request 14941
# 6961            5.0               rejected direct debit
# 16296           5.0  Instant Payment Cash Request 23371
# 20775           5.0  Instant Payment Cash Request 26772
# 11242           5.0  Instant Payment Cash Request 19350
#
#                           created_at                     updated_at  \
# id
# 6537    2020-09-07 10:47:27.42315+00  2020-10-13 14:25:09.396112+00
# 6961   2020-09-09 20:51:17.998653+00  2020-10-13 14:25:15.537063+00
# 16296  2020-10-23 10:10:58.352972+00  2020-10-23 10:10:58.352994+00
# 20775  2020-10-31 15:46:53.643958+00  2020-10-31 15:46:53.643982+00
# 11242  2020-10-06 08:20:17.170432+00  2020-10-13 14:25:03.267983+00
#
#                              paid_at from_date to_date charge_moment
# id
# 6537    2020-12-17 14:50:07.47011+00       NaN     NaN         after
# 6961    2020-12-08 17:13:10.45908+00       NaN     NaN         after
# 16296   2020-11-04 19:34:37.43291+00       NaN     NaN         after
# 20775  2020-11-19 05:09:22.500223+00       NaN     NaN         after
# 11242  2020-11-02 14:45:20.355598+00       NaN     NaN         after

# %%
fees_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21061 entries, 6537 to 13301
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cash_request_id  21057 non-null  float64
#  1   type             21061 non-null  object
#  2   status           21061 non-null  object
#  3   category         2196 non-null   object
#  4   total_amount     21061 non-null  float64
#  5   reason           21061 non-null  object
#  6   created_at       21061 non-null  object
#  7   updated_at       21061 non-null  object
#  8   paid_at          15531 non-null  object
#  9   from_date        7766 non-null   object
#  10  to_date          7766 non-null   object
#  11  charge_moment    21061 non-null  object
# dtypes: float64(2), object(10)
# memory usage: 2.1+ MB

# %%
print("Fee - Type")
print(fees_data["type"].unique())

print("Fee - Status")
print(fees_data["status"].unique())

print("Fee - reason")
print(fees_data["reason"].unique())

print("Fee - category")
print(fees_data["category"].unique())

print("Fee - charge_moment")
print(fees_data["charge_moment"].unique())
# Out:
# Fee - Type
# ['instant_payment' 'incident' 'postpone']
# Fee - Status
# ['rejected' 'accepted' 'cancelled' 'confirmed']
# Fee - reason
# ['Instant Payment Cash Request 14941' 'rejected direct debit'
#  'Instant Payment Cash Request 23371' ...
#  'Instant Payment Cash Request 25331' 'Instant Payment Cash Request 23628'
#  'Instant Payment Cash Request 20982']
# Fee - category
# [nan 'rejected_direct_debit' 'month_delay_on_payment']
# Fee - charge_moment
# ['after' 'before']

# %%
lista_cash = cash[cash["user_id"] == 47.0]["id"]

datos = fees_data[fees_data["cash_request_id"] in lista_cash] 
datos
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 lista_cash = cash[cash["user_id"] == 47.0]["id"]
# ----> 3 datos = fees_data[fees_data["cash_request_id"] in lista_cash]
#       4 datos
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:2080, in NDFrame.__contains__(self, key)
#    2077 @final
#    2078 def __contains__(self, key) -> bool_t:
#    2079     """True if the key is in the info axis"""
# -> 2080     return key in self._info_axis
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:5358, in Index.__contains__(self, key)
#    5323 def __contains__(self, key: Any) -> bool:
#    5324     """
#    5325     Return a boolean indicating whether the provided key is in the index.
#    5326
#    (...)
#    5356     False
#    5357     """
# -> 5358     hash(key)
#    5359     try:
#    5360         return key in self._engine
#
# TypeError: unhashable type: 'Series'
